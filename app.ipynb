# %%
import pandas as pd

# %%
df = pd.read_csv('Student1.csv')

# %%
df
# Out:
#    Student   Age  Marks        City
# 0  arsalan  23.0     35      Lahore
# 1    adeel  55.0     88   islamabad
# 2      Ali  78.0     56      gujrat
# 3    Afnan   NaN     43         NaN
# 4     abid   NaN     33  rawalpindi

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Student', 'Age', 'Marks', 'City'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  5 non-null      str
#  1   Age      3 non-null      float64
#  2   Marks    5 non-null      int64
#  3   City     4 non-null      str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 288.0 bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count   3.000000   5.000000
# mean   52.000000  51.000000
# std    27.622455  22.572107
# min    23.000000  33.000000
# 25%    39.000000  35.000000
# 50%    55.000000  43.000000
# 75%    66.500000  56.000000
# max    78.000000  88.000000

# %%
df.head()
# Out:
#    Student   Age  Marks        City
# 0  arsalan  23.0     35      Lahore
# 1    adeel  55.0     88   islamabad
# 2      Ali  78.0     56      gujrat
# 3    Afnan   NaN     43         NaN
# 4     abid   NaN     33  rawalpindi

# %%
df['Student']
# Out:
# 0    arsalan
# 1      adeel
# 2        Ali
# 3      Afnan
# 4       abid
# Name: Student, dtype: str

# %%
df[[ 'Age','Marks','City']]
# Out:
#     Age  Marks        City
# 0  23.0     35      Lahore
# 1  55.0     88   islamabad
# 2  78.0     56      gujrat
# 3   NaN     43         NaN
# 4   NaN     33  rawalpindi

# %%
df.loc[2:2]
# Out:
#   Student   Age  Marks    City
# 2     Ali  78.0     56  gujrat

# %%
df[df['Marks']<40]
# Out:
#    Student   Age  Marks        City
# 0  arsalan  23.0     35      Lahore
# 4     abid   NaN     33  rawalpindi

# %%
df.isnull()
# Out:
#    Student    Age  Marks   City
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False   True  False   True
# 4    False   True  False  False

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#    Student   Age  Marks        City
# 0  arsalan  23.0     35      Lahore
# 1    adeel  55.0     88   islamabad
# 2      Ali  78.0     56      gujrat
# 3    Afnan  52.0     43         NaN
# 4     abid  52.0     33  rawalpindi

# %%
df["City"]=df["City"].fillna(df["City"].mode())

# %%
df
# Out:
#    Student   Age  Marks        City
# 0  arsalan  23.0     35      Lahore
# 1    adeel  55.0     88   islamabad
# 2      Ali  78.0     56      gujrat
# 3    Afnan  52.0     43  rawalpindi
# 4     abid  52.0     33  rawalpindi

# %%
df["Result"] = df["Marks"].apply(lambda x: "Pass" if x>=50 else "Fail")

# %%
df
# Out:
#    Student   Age  Marks        City Result
# 0  arsalan  23.0     35      Lahore   Fail
# 1    adeel  55.0     88   islamabad   Pass
# 2      Ali  78.0     56      gujrat   Pass
# 3    Afnan  52.0     43  rawalpindi   Fail
# 4     abid  52.0     33  rawalpindi   Fail
